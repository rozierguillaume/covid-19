# %%
import pandas as pd

# %%
PATH = '../../'
df = pd.read_csv(PATH+'data/france/synthese-fra.csv')
df['deces'] = df['total_deces_hopital'] + df['total_deces_ehpad']
df['deces_nouveaux'] = df['deces'].diff()

# %%
df
# Out:
#            date  total_cas_confirmes  total_deces_hopital  total_deces_ehpad  \
# 0    2020-03-02                  191                    3                NaN
# 1    2020-03-03                  212                    4                NaN
# 2    2020-03-04                  285                    4                NaN
# 3    2020-03-05                  423                    7                NaN
# 4    2020-03-06                  613                    9                NaN
# ..          ...                  ...                  ...                ...
# 317  2020-10-28              1235132                24424            11361.0
# 318  2020-10-13               756472                22077            10856.0
# 319  2020-10-07               653509                21660            10785.0
# 320  2020-09-09               344101                20319            10475.0
# 321  2020-12-08              2309621                38739            17613.0
#
#      total_cas_confirmes_ehpad  total_cas_possibles_ehpad  \
# 0                          NaN                        NaN
# 1                          NaN                        NaN
# 2                          NaN                        NaN
# 3                          NaN                        NaN
# 4                          NaN                        NaN
# ..                         ...                        ...
# 317                    62297.0                        NaN
# 318                    48845.0                        NaN
# 319                    46520.0                        NaN
# 320                    40876.0                        NaN
# 321                   126828.0                        NaN
#
#      patients_reanimation  patients_hospitalises  total_patients_gueris  \
# 0                     NaN                    NaN                    NaN
# 1                     NaN                    NaN                   12.0
# 2                    15.0                    NaN                    NaN
# 3                    23.0                    NaN                    NaN
# 4                    39.0                    NaN                    NaN
# ..                    ...                    ...                    ...
# 317                3045.0                20207.0               113977.0
# 318                1642.0                 8949.0               102680.0
# 319                1416.0                 7536.0                99793.0
# 320                 599.0                 5003.0                88524.0
# 321                3088.0                25914.0               171868.0
#
#      nouveaux_patients_hospitalises  nouveaux_patients_reanimation    deces  \
# 0                               NaN                            NaN      NaN
# 1                               NaN                            NaN      NaN
# 2                               NaN                            NaN      NaN
# 3                               NaN                            NaN      NaN
# 4                               NaN                            NaN      NaN
# ..                              ...                            ...      ...
# 317                          2821.0                          372.0  35785.0
# 318                          1168.0                          226.0  32933.0
# 319                           789.0                          143.0  32445.0
# 320                           386.0                           71.0  30794.0
# 321                          1587.0                          214.0  56352.0
#
#      deces_nouveaux
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ..              ...
# 317          5079.0
# 318         -2852.0
# 319          -488.0
# 320         -1651.0
# 321         25558.0
#
# [322 rows x 13 columns]
