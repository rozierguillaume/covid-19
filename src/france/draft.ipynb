# %%
import pandas as pd
PATH = '../../'

# %%
df = pd.read_csv(PATH+'data/france/synthese-fra.csv')
df['deces'] = df['total_deces_hopital'] + df['total_deces_ehpad']
df['deces_nouveaux'] = df['deces'].diff()

# %%
df_epci = pd.read_csv(PATH+"data/france/sg-epci-opendata.csv")

# %%
df_epci[df_epci.epci2020 == 200030658]
# Out:
#         epci2020 nature      semaine_glissante  clage_65   ti_classe  \
# 32860  200030658     CC  2021-01-15-2021-01-21         0  [500;1000[
# 32861  200030658     CC  2021-01-15-2021-01-21        65   [250;500[
# 32862  200030658     CC  2021-01-16-2021-01-22         0  [500;1000[
# 32863  200030658     CC  2021-01-16-2021-01-22        65   [250;500[
# 32864  200030658     CC  2021-01-17-2021-01-23         0  [500;1000[
# ...          ...    ...                    ...       ...         ...
# 32917  200030658     CC  2021-02-12-2021-02-18        65     [20;50[
# 32918  200030658     CC  2021-02-13-2021-02-19         0    [50;150[
# 32919  200030658     CC  2021-02-13-2021-02-19        65    [50;150[
# 32920  200030658     CC  2021-02-14-2021-02-20         0    [50;150[
# 32921  200030658     CC  2021-02-14-2021-02-20        65    [50;150[
#
#          td_classe tp_classe
# 32860   [2500;Max]   [15;20[
# 32861  [1500;2000[   [15;20[
# 32862   [2500;Max]   [15;20[
# 32863  [1500;2000[   [15;20[
# 32864   [2500;Max]   [20;25[
# ...            ...       ...
# 32917  [1000;1500[     [1;5[
# 32918  [1500;2000[    [5;10[
# 32919  [1000;1500[    [5;10[
# 32920  [1500;2000[     [1;5[
# 32921  [1500;2000[    [5;10[
#
# [62 rows x 7 columns]
