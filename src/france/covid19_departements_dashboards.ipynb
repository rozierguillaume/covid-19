# %%
"""

LICENSE MIT
2020
Guillaume Rozier
Website : http://www.covidtracker.fr
Mail : guillaume.rozier@telecomnancy.net

README:
This file contains scripts that download data from data.gouv.fr and then process it to build many graphes.
I'm currently cleaning the code, please ask me if something is not clear enough.

The charts are exported to 'charts/images/france'.
Data is download to/imported from 'data/france'.
Requirements: please see the imports below (use pip3 to install them).

"""
# Out:
# "\n\nLICENSE MIT\n2020\nGuillaume Rozier\nWebsite : http://www.covidtracker.fr\nMail : guillaume.rozier@telecomnancy.net\n\nREADME:\nThis file contains scripts that download data from data.gouv.fr and then process it to build many graphes.\nI'm currently cleaning the code, please ask me if something is not clear enough.\n\nThe charts are exported to 'charts/images/france'.\nData is download to/imported from 'data/france'.\nRequirements: please see the imports below (use pip3 to install them).\n\n"

# %%
import pandas as pd
import plotly.graph_objects as go
import france_data_management as data
from datetime import datetime
from datetime import timedelta
import plotly
import math
import os
PATH = "../../"

# %%
df, df_confirmed, dates, df_new, df_tests, df_deconf, df_sursaud, df_incid, df_tests_viros = data.import_data()
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]/Users/guillaumerozier/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3249: DtypeWarning:
#
# Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 28it [01:30,  3.88s/it]

# %%
#df = df.groupby(["dep", "jour"]).first().reset_index()

# %%
df_departements = df.groupby(["jour", "departmentName"]).sum().reset_index()
df_incid_departements = df_incid[df_incid["cl_age90"]==0].groupby(["jour", "departmentName"]).sum().reset_index()

df_new_departements = df_new.groupby(["jour", "departmentName"]).sum().reset_index()

departements = list(dict.fromkeys(list(df_departements['departmentName'].values))) 

dates_incid = list(dict.fromkeys(list(df_incid['jour'].values))) 
last_day_plot = (datetime.strptime(max(dates), '%Y-%m-%d') + timedelta(days=1)).strftime("%Y-%m-%d")

departements_nb = list(dict.fromkeys(list(df_tests_viros['dep'].values)))

# %%
lits_reas = pd.read_csv(PATH+'data/france/lits_rea.csv', sep=",")

df_departements_lits = df_departements.merge(lits_reas, left_on="departmentName", right_on="nom_dpt")

# %%
def cas_journ(departement):
        
    df_incid_dep = df_incid_departements[df_incid_departements["departmentName"] == departement]
    df_incid_dep_rolling = df_incid_dep["P"].rolling(window=7, center=True).mean()
    
    range_x, name_fig, range_y = ["2020-03-29", last_day_plot], "cas_journ_"+departement, [0, df_incid_dep["P"].max()]
    title = "<b>Cas positifs</b> au Covid19 - <b>" + departement + "</b>"

    fig = go.Figure()


    fig.add_trace(go.Scatter(
        x = df_incid_dep["jour"],
        y = df_incid_dep_rolling,
        name = "Nouveaux décès hosp.",
        marker_color='rgb(8, 115, 191)',
        line_width=8,
        opacity=0.8,
        fill='tozeroy',
        fillcolor="rgba(8, 115, 191, 0.3)",
        showlegend=False
    ))
    fig.add_trace(go.Scatter(
        x = [dates_incid[-4]],
        y = [df_incid_dep_rolling.values[-4]],
        name = "Nouveaux décès hosp.",
        mode="markers",
        marker_color='rgb(8, 115, 191)',
        marker_size=15,
        opacity=1,
        showlegend=False
    ))

    fig.add_trace(go.Scatter(
        x = df_incid_dep["jour"],
        y = df_incid_dep["P"],
        name = "",
        mode="markers",
        marker_color='rgb(8, 115, 191)',
        line_width=3,
        opacity=0.4,
        showlegend=False
    ))

    ###

    fig.update_yaxes(zerolinecolor='Grey', range=range_y, tickfont=dict(size=18))
    fig.update_xaxes(nticks=10, ticks='inside', tickangle=0, tickfont=dict(size=18))

    # Here we modify the tickangle of the xaxis, resulting in rotated labels.
    fig.update_layout(
        margin=dict(
                l=50,
                r=0,
                b=50,
                t=70,
                pad=0
            ),
        legend_orientation="h",
        barmode='group',
        title={
                    'text': title,
                    'y':0.95,
                    'x':0.5,
                    'xanchor': 'center',
                    'yanchor': 'top'},
                    titlefont = dict(
                    size=20),
        xaxis=dict(
                title='',
                tickformat='%d/%m'),

        annotations = [
                    dict(
                        x=0,
                        y=1.07,
                        xref='paper',
                        yref='paper',
                        font=dict(size=14),
                        text='{}. Données : Santé publique France. Auteur : <b>@GuillaumeRozier - covidtracker.fr.</b>'.format(datetime.strptime(max(dates), '%Y-%m-%d').strftime('%d %b')),                    showarrow = False
                    ),
                    ]
                     )

    fig['layout']['annotations'] += (dict(
            x = dates_incid[-4], y = df_incid_dep_rolling.values[-4], # annotation point
            xref='x1', 
            yref='y1',
            text=" <b>{} {}".format('%d' % df_incid_dep_rolling.values[-4], "cas quotidiens<br></b>en moyenne du {} au {}.".format(datetime.strptime(dates_incid[-7], '%Y-%m-%d').strftime('%d'), datetime.strptime(dates_incid[-1], '%Y-%m-%d').strftime('%d %b'))),
            xshift=-2,
            yshift=10,
            xanchor="center",
            align='center',
            font=dict(
                color="rgb(8, 115, 191)",
                size=20
                ),
            bgcolor="rgba(255, 255, 255, 0.6)",
            opacity=1,
            ax=-40,
            ay=-70,
            arrowcolor="rgb(8, 115, 191)",
            arrowsize=1.5,
            arrowwidth=1,
            arrowhead=0,
            showarrow=True
        ),)

    fig.write_image(PATH+"images/charts/france/departements_dashboards/{}.jpeg".format(name_fig), scale=1.5, width=750, height=500)

    print("> " + name_fig)

# %%
def hosp_journ(departement):   
    df_dep = df_departements[df_departements["departmentName"] == departement]
    #df_incid_reg_rolling = df_incid_reg["P"].rolling(window=7, center=True).mean()
    
    range_x, name_fig = ["2020-03-29", last_day_plot], "hosp_journ_"+departement
    title = "Personnes <b>hospitalisées</b> pour Covid19 - <b>" + departement +"</b>"

    fig = go.Figure()

    fig.add_trace(go.Scatter(
        x = df_dep["jour"],
        y = df_dep["hosp"],
        name = "Nouveaux décès hosp.",
        marker_color='rgb(209, 102, 21)',
        line_width=8,
        opacity=0.8,
        fill='tozeroy',
        fillcolor="rgba(209, 102, 21,0.3)",
        showlegend=False
    ))
    fig.add_trace(go.Scatter(
        x = [dates[-1]],
        y = [df_dep["hosp"].values[-1]],
        name = "Nouveaux décès hosp.",
        mode="markers",
        marker_color='rgb(209, 102, 21)',
        marker_size=15,
        opacity=1,
        showlegend=False
    ))

    ###

    fig.update_yaxes(zerolinecolor='Grey', tickfont=dict(size=18))
    fig.update_xaxes(nticks=10, ticks='inside', tickangle=0, tickfont=dict(size=18))

    # Here we modify the tickangle of the xaxis, resulting in rotated labels.
    fig.update_layout(
        margin=dict(
                l=50,
                r=0,
                b=50,
                t=70,
                pad=0
            ),
        legend_orientation="h",
        barmode='group',
        title={
                    'text': title,
                    'y':0.95,
                    'x':0.5,
                    'xanchor': 'center',
                    'yanchor': 'top'},
                    titlefont = dict(
                    size=20),
        xaxis=dict(
                title='',
                tickformat='%d/%m'),

        annotations = [
                    dict(
                        x=0,
                        y=1.07,
                        xref='paper',
                        yref='paper',
                        font=dict(size=14),
                        text='{}. Données : Santé publique France. Auteur : <b>@GuillaumeRozier - covidtracker.fr.</b>'.format(datetime.strptime(max(dates), '%Y-%m-%d').strftime('%d %b')),                    showarrow = False
                    ),
                    ]
                     )

    fig['layout']['annotations'] += (dict(
            x = dates[-1], y = df_dep["hosp"].values[-1], # annotation point
            xref='x1', 
            yref='y1',
            text=" <b>{} {}".format('%d' % df_dep["hosp"].values[-1], "personnes<br>hospitalisées</b><br>le {}.".format(datetime.strptime(dates[-1], '%Y-%m-%d').strftime('%d %b'))),
            xshift=-2,
            yshift=10,
            xanchor="center",
            align='center',
            font=dict(
                color="rgb(209, 102, 21)",
                size=20
                ),
            bgcolor="rgba(255, 255, 255, 0.6)",
            opacity=0.8,
            ax=-50,
            ay=-90,
            arrowcolor="rgb(209, 102, 21)",
            arrowsize=1.5,
            arrowwidth=1,
            arrowhead=0,
            showarrow=True
        ),)

    fig.write_image(PATH+"images/charts/france/departements_dashboards/{}.jpeg".format(name_fig), scale=1.5, width=750, height=500)

    print("> " + name_fig)

# %%
def hosp_comparaison_vagues(departement):   
    df_dep = df_departements[df_departements["departmentName"] == departement]
    #df_incid_reg_rolling = df_incid_reg["P"].rolling(window=7, center=True).mean()
    
    range_x, name_fig = ["2020-03-29", last_day_plot], "hosp_comp_vagues_"+departement
    title = ""#"<b>Personnes hospitalisées</b> pour Covid19 - " + departement

    fig = go.Figure()
    
    premiere_vague = df_dep[ df_dep["jour"] < "2020-08"]["hosp"].max()
    premiere_vague_date = df_dep[ df_dep["hosp"] == premiere_vague]["jour"].min()
    
    deuxieme_vague = df_dep[ df_dep["jour"] > "2020-09"]["hosp"].max()
    deuxieme_vague_date = df_dep[ (df_dep["hosp"] == deuxieme_vague) & (df_dep["jour"] > "2020-09")]["jour"].min()
    
    color_deuxieme_vague = "green"
    if deuxieme_vague > premiere_vague:
        color_deuxieme_vague = "red"
    
    hosp_values = df_dep["hosp"].values
    trace_to_add = [max(0, hosp - premiere_vague) for hosp in hosp_values]
    
    
    #deuxieme_vague += [df_dep[ df_dep["jour"] > "2020-09"]["hosp"].max()]
    color = ["red" if hosp > premiere_vague else "rgb(209, 102, 21)" for hosp in df_dep["hosp"].values]
    fig.add_trace(go.Bar(
        x = df_dep["jour"],
        y = df_dep["hosp"].values - trace_to_add,
        name = "Nouveaux décès hosp.",
        marker_color="orange",
        #line_width=8,
        opacity=0.8,
        #fill='tozeroy',
        #fillcolor="rgba(209, 102, 21,0.3)",
        showlegend=False
    ))
    
    fig.add_trace(go.Bar(
        x = df_dep["jour"],
        y = trace_to_add,
        name = "Nouveaux décès hosp.",
        marker_color="red",
        #line_width=8,
        opacity=0.8,
        #fill='tozeroy',
        #fillcolor="rgba(209, 102, 21,0.3)",
        showlegend=False
    ))
    
    fig.add_shape(
            type="line",
            x0="2000-01-01",
            y0=premiere_vague,
            x1="2030-01-01",
            y1=premiere_vague,
            opacity=1,
            #fillcolor="orange",
            line=dict(
                dash="dash",
                color="black",
                width=1,
            )
        )

    ###

    fig.update_yaxes(zerolinecolor='Grey', tickfont=dict(size=18))
    fig.update_xaxes(nticks=10, ticks='inside', tickangle=0, tickfont=dict(size=18),  range=["2020-03-15", last_day_plot])

    # Here we modify the tickangle of the xaxis, resulting in rotated labels.
    fig.update_layout(
        paper_bgcolor='rgba(255,255,255,1)',
        plot_bgcolor='rgba(255,255,255,1)',
        bargap=0,
        margin=dict(
                l=50,
                r=0,
                b=50,
                t=70,
                pad=0
            ),
        legend_orientation="h",
        barmode='stack',
        title={
                    'text': title,
                    'y':0.95,
                    'x':0.5,
                    'xanchor': 'center',
                    'yanchor': 'top'},
                    titlefont = dict(
                    size=20),
        xaxis=dict(
                title='',
                tickformat='%d/%m'),

        annotations = [
                    dict(
                        x=0,
                        y=-0.08,
                        xref='paper',
                        yref='paper',
                        text="Date : {}. Source : Santé publique France. Auteur : Guillaume Rozier - covidtracker.fr - nombre d'hospitalisations".format(datetime.strptime(max(dates), '%Y-%m-%d').strftime('%d %B %Y')),                    showarrow = False
                    ),
                    ]
                     )

    fig['layout']['annotations'] += (dict(
            x = deuxieme_vague_date, y = deuxieme_vague, # annotation point
            xref='x1', 
            yref='y1',
            text="Deuxième vague",
            xshift=-5,
            yshift=10,
            xanchor="center",
            align='center',
            font=dict(
                color=color_deuxieme_vague,
                size=20
                ),
            bgcolor="rgba(255, 255, 255, 0.6)",
            opacity=0.8,
            ax=-150,
            ay=-50,
            arrowcolor=color_deuxieme_vague,
            arrowsize=1.5,
            arrowwidth=1,
            arrowhead=0,
            showarrow=True
        ),dict(
            x = premiere_vague_date, y = premiere_vague, # annotation point
            xref='x1', 
            yref='y1',
            text="Première vague",
            xshift=0,
            yshift=10,
            xanchor="center",
            align='center',
            font=dict(
                color="black",
                size=20
                ),
            bgcolor="rgba(255, 255, 255, 0.6)",
            opacity=0.8,
            ax=0,
            ay=-50,
            arrowcolor="black",
            arrowsize=1.5,
            arrowwidth=1,
            arrowhead=0,
            showarrow=True
        ))

    fig.write_image(PATH+"images/charts/france/departements_dashboards/{}.jpeg".format(name_fig), scale=1.5, width=1000, height=700)

    print("> " + name_fig)
    
#hosp_comparaison_vagues("Savoie")

# %%
def rea_journ(departement):
    df_dep = df_departements[df_departements["departmentName"] == departement]
    
    range_x, name_fig = ["2020-03-29", last_day_plot], "rea_journ_" + departement
    title = "Personnes en <b>réanimation</b> pour Covid19 - <b>" + departement + "</b>"

    fig = go.Figure()

    fig.add_trace(go.Scatter(
        x = dates,
        y = df_dep["rea"],
        name = "Nouveaux décès hosp.",
        marker_color='rgb(201, 4, 4)',
        line_width=8,
        opacity=0.8,
        fill='tozeroy',
        fillcolor="rgba(201, 4, 4,0.3)",
        showlegend=False
    ))
    fig.add_trace(go.Scatter(
        x = [dates[-1]],
        y = [df_dep["rea"].values[-1]],
        name = "Nouveaux décès hosp.",
        mode="markers",
        marker_color='rgb(201, 4, 4)',
        marker_size=15,
        opacity=1,
        showlegend=False
    ))

    ###

    fig.update_yaxes(zerolinecolor='Grey', tickfont=dict(size=18))
    fig.update_xaxes(nticks=10, ticks='inside', tickangle=0, tickfont=dict(size=18))

    # Here we modify the tickangle of the xaxis, resulting in rotated labels.
    fig.update_layout(
        margin=dict(
                l=50,
                r=10,
                b=50,
                t=70,
                pad=0
            ),
        legend_orientation="h",
        barmode='group',
        title={
                    'text': title,
                    'y':0.95,
                    'x':0.5,
                    'xanchor': 'center',
                    'yanchor': 'top'},
                    titlefont = dict(
                    size=20),
        xaxis=dict(
                title='',
                tickformat='%d/%m'),

        annotations = [
                    dict(
                        x=0,
                        y=1.07,
                        xref='paper',
                        yref='paper',
                        font=dict(size=14),
                        text='{}. Données : Santé publique France. Auteur : <b>@GuillaumeRozier - covidtracker.fr.</b>'.format(datetime.strptime(max(dates), '%Y-%m-%d').strftime('%d %b')),                    showarrow = False
                    ),
                    ]
                     )

    fig['layout']['annotations'] += (dict(
            x = dates[-1], y = df_dep["rea"].values[-1], # annotation point
            xref='x1', 
            yref='y1',
            text=" <b>{} {}".format('%d' % df_dep["rea"].values[-1], "personnes<br>en réanimation</b><br>le {}.".format(datetime.strptime(dates[-1], '%Y-%m-%d').strftime('%d %b'))),
            xshift=-2,
            yshift=10,
            xanchor="center",
            align='center',
            font=dict(
                color="rgb(201, 4, 4)",
                size=20
                ),
            bgcolor="rgba(255, 255, 255, 0.6)",
            opacity=0.8,
            ax=-50,
            ay=-90,
            arrowcolor="rgb(201, 4, 4)",
            arrowsize=1.5,
            arrowwidth=1,
            arrowhead=0,
            showarrow=True
        ),)

    fig.write_image(PATH+"images/charts/france/departements_dashboards/{}.jpeg".format(name_fig), scale=1.5, width=750, height=500)

    print("> " + name_fig)
    
#rea_journ("Isère")

# %%
def dc_journ(departement): 
    df_dep = df_new_departements[df_new_departements["departmentName"] == departement]
    dc_new_rolling = df_dep["incid_dc"].rolling(window=7).mean()
    
    range_x, name_fig, range_y = ["2020-03-29", last_day_plot], "dc_journ_"+departement, [0, df_dep["incid_dc"].max()]
    title = "Décès <b>hospitaliers quotidiens</b> du Covid19 - <b>" + departement + "</b>"

    fig = go.Figure()
    
    fig.add_trace(go.Scatter(
        x = df_dep["jour"],
        y = dc_new_rolling,
        name = "Nouveaux décès hosp.",
        marker_color='black',
        line_width=8,
        opacity=0.8,
        fill='tozeroy',
        fillcolor="rgba(0,0,0,0.3)",
        showlegend=False
    ))
    fig.add_trace(go.Scatter(
        x = [dates[-1]],
        y = [dc_new_rolling.values[-1]],
        name = "Nouveaux décès hosp.",
        mode="markers",
        marker_color='black',
        marker_size=15,
        opacity=1,
        showlegend=False
    ))

    #
    fig.add_trace(go.Scatter(
        x = df_dep["jour"],
        y = df_dep["incid_dc"],
        name = "Nouveaux décès hosp.",
        mode="markers",
        marker_color='black',
        line_width=3,
        opacity=0.4,
        showlegend=False
    ))

    ###

    fig.update_yaxes(zerolinecolor='Grey', range=range_y, tickfont=dict(size=18))
    fig.update_xaxes(nticks=10, ticks='inside', tickangle=0, tickfont=dict(size=18))

    # Here we modify the tickangle of the xaxis, resulting in rotated labels.
    fig.update_layout(
        margin=dict(
                l=50,
                r=0,
                b=50,
                t=70,
                pad=0
            ),
        legend_orientation="h",
        barmode='group',
        title={
                    'text': title,
                    'y':0.95,
                    'x':0.5,
                    'xanchor': 'center',
                    'yanchor': 'top'},
                    titlefont = dict(
                    size=20),
        xaxis=dict(
                title='',
                tickformat='%d/%m'),

        annotations = [
                    dict(
                        x=0,
                        y=1.07,
                        xref='paper',
                        yref='paper',
                         font=dict(size=14),
                        text='{}. Données : Santé publique France. Auteur : <b>@GuillaumeRozier - covidtracker.fr.</b>'.format(datetime.strptime(max(dates), '%Y-%m-%d').strftime('%d %b')),                    showarrow = False
                    ),
                    ]
                     )

    fig['layout']['annotations'] += (dict(
            x = dates[-1], y = dc_new_rolling.values[-1], # annotation point
            xref='x1', 
            yref='y1',
            text=" <b>{} {}".format('%d' % math.trunc(round(dc_new_rolling.values[-1], 2)), "décès quotidiens</b><br>en moyenne<br>du {} au {}.".format(datetime.strptime(dates[-7], '%Y-%m-%d').strftime('%d'), datetime.strptime(dates[-1], '%Y-%m-%d').strftime('%d %b'))),
            xshift=-2,
            yshift=10,
            xanchor="center",
            align='center',
            font=dict(
                color="black",
                size=20
                ),
            bgcolor="rgba(255, 255, 255, 0.6)",
            opacity=0.8,
            ax=-50,
            ay=-90,
            arrowcolor="black",
            arrowsize=1.5,
            arrowwidth=1,
            arrowhead=0,
            showarrow=True
        ),)

    fig.write_image(PATH+"images/charts/france/departements_dashboards/{}.jpeg".format(name_fig), scale=1.5, width=750, height=500)

    print("> " + name_fig)
    
#dc_journ("Paris")

# %%
def saturation_rea_journ(dep):
    df_dep = df_departements_lits[df_departements_lits["departmentName"] == dep]
    df_saturation = 100 * df_dep["rea"] / df_dep["LITS_y"]
    
    range_x, name_fig, range_y = ["2020-03-29", last_day_plot], "saturation_rea_journ_"+dep, [0, df_saturation.max()]
    title = "<b>Occupation des réa.</b> par les patients Covid19 - " + dep

    fig = go.Figure()

    colors_sat = ["green" if val < 40 else "red" if val > 80  else "orange" for val in df_saturation.values]
    fig.add_trace(go.Bar(
        x = df_dep["jour"],
        y = df_saturation,
        name = "Saturation",
        marker_color=colors_sat,
        #line_width=8,
        opacity=0.8,
        #fill='tozeroy',
        #fillcolor="rgba(8, 115, 191, 0.3)",
        showlegend=False
    ))

    fig.update_yaxes(zerolinecolor='Grey', range=range_y, tickfont=dict(size=18))
    fig.update_xaxes(nticks=10, ticks='inside', tickangle=0, tickfont=dict(size=18))

    # Here we modify the tickangle of the xaxis, resulting in rotated labels.
    fig.update_layout(
        margin=dict(
                l=50,
                r=0,
                b=50,
                t=70,
                pad=0
            ),
        legend_orientation="h",
        barmode='group',
        title={
                    'text': title,
                    'y':0.95,
                    'x':0.5,
                    'xanchor': 'center',
                    'yanchor': 'top'},
                    titlefont = dict(
                    size=20),
        xaxis=dict(
                title='',
                tickformat='%d/%m'),

        annotations = [
                    dict(
                        x=0,
                        y=1,
                        xref='paper',
                        yref='paper',
                        text='Date : {}. Source : Santé publique France. Auteur : guillaumerozier.fr.'.format(datetime.strptime(max(dates), '%Y-%m-%d').strftime('%d %B %Y')),                    showarrow = False
                    ),
                    ]
                     )

    fig['layout']['annotations'] += (dict(
            x = dates[-1], y = df_saturation.values[-1], # annotation point
            xref='x1', 
            yref='y1',
            text=" <b>{} {}".format('%d' % df_saturation.values[-1], " %</b> des lits de réa. occupés par<br>des patients Covid19 le {}.".format(datetime.strptime(dates[-1], '%Y-%m-%d').strftime('%d %b'))),
            xshift=-2,
            yshift=10,
            xanchor="center",
            align='center',
            font=dict(
                color=colors_sat[-1],
                size=20
                ),
            opacity=1,
            ax=-70,
            ay=-70,
            arrowcolor=colors_sat[-1],
            arrowsize=1.5,
            arrowwidth=1,
            arrowhead=0,
            showarrow=True
        ),)

    fig.write_image(PATH+"images/charts/france/departements_dashboards/{}.jpeg".format(name_fig), scale=1.5, width=750, height=500)

    print("> " + name_fig)

# %%
import cv2

for dep in departements:
    cas_journ(dep)
    hosp_journ(dep)
    rea_journ(dep)
    dc_journ(dep)
    hosp_comparaison_vagues(dep)
    saturation_rea_journ(dep)
    
    im1 = cv2.imread(PATH+'images/charts/france/departements_dashboards/cas_journ_{}.jpeg'.format(dep))
    im2 = cv2.imread(PATH+'images/charts/france/departements_dashboards/hosp_journ_{}.jpeg'.format(dep))
    im3 = cv2.imread(PATH+'images/charts/france/departements_dashboards/rea_journ_{}.jpeg'.format(dep))
    im4 = cv2.imread(PATH+'images/charts/france/departements_dashboards/dc_journ_{}.jpeg'.format(dep))

    im_haut = cv2.hconcat([im1, im2])
    #cv2.imwrite('images/charts/france/tests_combinaison.jpeg', im_h)
    im_bas = cv2.hconcat([im3, im4])

    im_totale = cv2.vconcat([im_haut, im_bas])
    cv2.imwrite(PATH+'images/charts/france/departements_dashboards/dashboard_jour_{}.jpeg'.format(dep), im_totale)
    
    os.remove(PATH+'images/charts/france/departements_dashboards/cas_journ_{}.jpeg'.format(dep))
    #os.remove('images/charts/france/departements_dashboards/hosp_journ_{}.jpeg'.format(dep))
    os.remove(PATH+'images/charts/france/departements_dashboards/rea_journ_{}.jpeg'.format(dep))
    os.remove(PATH+'images/charts/france/departements_dashboards/dc_journ_{}.jpeg'.format(dep))
# Out:
# > cas_journ_Ain
# > hosp_journ_Ain
# > rea_journ_Ain
# > dc_journ_Ain
# > hosp_comp_vagues_Ain
# > saturation_rea_journ_Ain
# > cas_journ_Aisne
# > hosp_journ_Aisne
# > rea_journ_Aisne
# > dc_journ_Aisne
# > hosp_comp_vagues_Aisne
# > saturation_rea_journ_Aisne
# > cas_journ_Allier
# > hosp_journ_Allier
# > rea_journ_Allier
# > dc_journ_Allier
# > hosp_comp_vagues_Allier
# > saturation_rea_journ_Allier
# > cas_journ_Alpes-Maritimes
# > hosp_journ_Alpes-Maritimes
# > rea_journ_Alpes-Maritimes
# > dc_journ_Alpes-Maritimes
# > hosp_comp_vagues_Alpes-Maritimes
# > saturation_rea_journ_Alpes-Maritimes
# > cas_journ_Alpes-de-Haute-Provence
# > hosp_journ_Alpes-de-Haute-Provence
# > rea_journ_Alpes-de-Haute-Provence
# > dc_journ_Alpes-de-Haute-Provence
# > hosp_comp_vagues_Alpes-de-Haute-Provence
# > saturation_rea_journ_Alpes-de-Haute-Provence
# > cas_journ_Ardennes
# > hosp_journ_Ardennes
# > rea_journ_Ardennes
# > dc_journ_Ardennes
# > hosp_comp_vagues_Ardennes
# > saturation_rea_journ_Ardennes
# > cas_journ_Ardèche
# > hosp_journ_Ardèche
# > rea_journ_Ardèche
# > dc_journ_Ardèche
# > hosp_comp_vagues_Ardèche
# > saturation_rea_journ_Ardèche
# > cas_journ_Ariège
# > hosp_journ_Ariège
# > rea_journ_Ariège
# > dc_journ_Ariège
# > hosp_comp_vagues_Ariège
# > saturation_rea_journ_Ariège
# > cas_journ_Aube
# > hosp_journ_Aube
# > rea_journ_Aube
# > dc_journ_Aube
# > hosp_comp_vagues_Aube
# > saturation_rea_journ_Aube
# > cas_journ_Aude
# > hosp_journ_Aude
# > rea_journ_Aude
# > dc_journ_Aude
# > hosp_comp_vagues_Aude
# > saturation_rea_journ_Aude
# > cas_journ_Aveyron
# > hosp_journ_Aveyron
# > rea_journ_Aveyron
# > dc_journ_Aveyron
# > hosp_comp_vagues_Aveyron
# > saturation_rea_journ_Aveyron
# > cas_journ_Bas-Rhin
# > hosp_journ_Bas-Rhin
# > rea_journ_Bas-Rhin
# > dc_journ_Bas-Rhin
# > hosp_comp_vagues_Bas-Rhin
# > saturation_rea_journ_Bas-Rhin
# > cas_journ_Bouches-du-Rhône
# > hosp_journ_Bouches-du-Rhône
# > rea_journ_Bouches-du-Rhône
# > dc_journ_Bouches-du-Rhône
# > hosp_comp_vagues_Bouches-du-Rhône
# > saturation_rea_journ_Bouches-du-Rhône
# > cas_journ_Calvados
# > hosp_journ_Calvados
# > rea_journ_Calvados
# > dc_journ_Calvados
# > hosp_comp_vagues_Calvados
# > saturation_rea_journ_Calvados
# > cas_journ_Cantal
# > hosp_journ_Cantal
# > rea_journ_Cantal
# > dc_journ_Cantal
# > hosp_comp_vagues_Cantal
# > saturation_rea_journ_Cantal
# > cas_journ_Charente
# > hosp_journ_Charente
# > rea_journ_Charente
# > dc_journ_Charente
# > hosp_comp_vagues_Charente
# > saturation_rea_journ_Charente
# > cas_journ_Charente-Maritime
# > hosp_journ_Charente-Maritime
# > rea_journ_Charente-Maritime
# > dc_journ_Charente-Maritime
# > hosp_comp_vagues_Charente-Maritime
# > saturation_rea_journ_Charente-Maritime
# > cas_journ_Cher
# > hosp_journ_Cher
# > rea_journ_Cher
# > dc_journ_Cher
# > hosp_comp_vagues_Cher
# > saturation_rea_journ_Cher
# > cas_journ_Corrèze
# > hosp_journ_Corrèze
# > rea_journ_Corrèze
# > dc_journ_Corrèze
# > hosp_comp_vagues_Corrèze
# > saturation_rea_journ_Corrèze
# > cas_journ_Corse-du-Sud
# > hosp_journ_Corse-du-Sud
# > rea_journ_Corse-du-Sud
# > dc_journ_Corse-du-Sud
# > hosp_comp_vagues_Corse-du-Sud
# > saturation_rea_journ_Corse-du-Sud
# > cas_journ_Creuse
# > hosp_journ_Creuse
# > rea_journ_Creuse
# > dc_journ_Creuse
# > hosp_comp_vagues_Creuse
# > saturation_rea_journ_Creuse
# > cas_journ_Côte-d'or
# > hosp_journ_Côte-d'or
# > rea_journ_Côte-d'or
# > dc_journ_Côte-d'or
# > hosp_comp_vagues_Côte-d'or
# > saturation_rea_journ_Côte-d'or
# > cas_journ_Côtes-d'armor
# > hosp_journ_Côtes-d'armor
# > rea_journ_Côtes-d'armor
# > dc_journ_Côtes-d'armor
# > hosp_comp_vagues_Côtes-d'armor
# > saturation_rea_journ_Côtes-d'armor
# > cas_journ_Deux-Sèvres
# > hosp_journ_Deux-Sèvres
# > rea_journ_Deux-Sèvres
# > dc_journ_Deux-Sèvres
# > hosp_comp_vagues_Deux-Sèvres
# > saturation_rea_journ_Deux-Sèvres
# > cas_journ_Dordogne
# > hosp_journ_Dordogne
# > rea_journ_Dordogne
# > dc_journ_Dordogne
# > hosp_comp_vagues_Dordogne
# > saturation_rea_journ_Dordogne
# > cas_journ_Doubs
# > hosp_journ_Doubs
# > rea_journ_Doubs
# > dc_journ_Doubs
# > hosp_comp_vagues_Doubs
# > saturation_rea_journ_Doubs
# > cas_journ_Drôme
# > hosp_journ_Drôme
# > rea_journ_Drôme
# > dc_journ_Drôme
# > hosp_comp_vagues_Drôme
# > saturation_rea_journ_Drôme
# > cas_journ_Essonne
# > hosp_journ_Essonne
# > rea_journ_Essonne
# > dc_journ_Essonne
# > hosp_comp_vagues_Essonne
# > saturation_rea_journ_Essonne
# > cas_journ_Eure
# > hosp_journ_Eure
# > rea_journ_Eure
# > dc_journ_Eure
# > hosp_comp_vagues_Eure
# > saturation_rea_journ_Eure
# > cas_journ_Eure-et-Loir
# > hosp_journ_Eure-et-Loir
# > rea_journ_Eure-et-Loir
# > dc_journ_Eure-et-Loir
# > hosp_comp_vagues_Eure-et-Loir
# > saturation_rea_journ_Eure-et-Loir
# > cas_journ_Finistère
# > hosp_journ_Finistère
# > rea_journ_Finistère
# > dc_journ_Finistère
# > hosp_comp_vagues_Finistère
# > saturation_rea_journ_Finistère
# > cas_journ_Gard
# > hosp_journ_Gard
# > rea_journ_Gard
# > dc_journ_Gard
# > hosp_comp_vagues_Gard
# > saturation_rea_journ_Gard
# > cas_journ_Gers
# > hosp_journ_Gers
# > rea_journ_Gers
# > dc_journ_Gers
# > hosp_comp_vagues_Gers
# > saturation_rea_journ_Gers
# > cas_journ_Gironde
# > hosp_journ_Gironde
# > rea_journ_Gironde
# > dc_journ_Gironde
# > hosp_comp_vagues_Gironde
# > saturation_rea_journ_Gironde
# > cas_journ_Guadeloupe
# > hosp_journ_Guadeloupe
# > rea_journ_Guadeloupe
# > dc_journ_Guadeloupe
# > hosp_comp_vagues_Guadeloupe
# > saturation_rea_journ_Guadeloupe
# > cas_journ_Guyane
# > hosp_journ_Guyane
# > rea_journ_Guyane
# > dc_journ_Guyane
# > hosp_comp_vagues_Guyane
# > saturation_rea_journ_Guyane
# > cas_journ_Haut-Rhin
# > hosp_journ_Haut-Rhin
# > rea_journ_Haut-Rhin
# > dc_journ_Haut-Rhin
# > hosp_comp_vagues_Haut-Rhin
# > saturation_rea_journ_Haut-Rhin
# > cas_journ_Haute-Corse
# > hosp_journ_Haute-Corse
# > rea_journ_Haute-Corse
# > dc_journ_Haute-Corse
# > hosp_comp_vagues_Haute-Corse
# > saturation_rea_journ_Haute-Corse
# > cas_journ_Haute-Garonne
# > hosp_journ_Haute-Garonne
# > rea_journ_Haute-Garonne
# > dc_journ_Haute-Garonne
# > hosp_comp_vagues_Haute-Garonne
# > saturation_rea_journ_Haute-Garonne
# > cas_journ_Haute-Loire
# > hosp_journ_Haute-Loire
# > rea_journ_Haute-Loire
# > dc_journ_Haute-Loire
# > hosp_comp_vagues_Haute-Loire
# > saturation_rea_journ_Haute-Loire
# > cas_journ_Haute-Marne
# > hosp_journ_Haute-Marne
# > rea_journ_Haute-Marne
# > dc_journ_Haute-Marne
# > hosp_comp_vagues_Haute-Marne
# > saturation_rea_journ_Haute-Marne
# > cas_journ_Haute-Savoie
# > hosp_journ_Haute-Savoie
# > rea_journ_Haute-Savoie
# > dc_journ_Haute-Savoie
# > hosp_comp_vagues_Haute-Savoie
# > saturation_rea_journ_Haute-Savoie
# > cas_journ_Haute-Saône
# > hosp_journ_Haute-Saône
# > rea_journ_Haute-Saône
# > dc_journ_Haute-Saône
# > hosp_comp_vagues_Haute-Saône
# > saturation_rea_journ_Haute-Saône
# > cas_journ_Haute-Vienne
# > hosp_journ_Haute-Vienne
# > rea_journ_Haute-Vienne
# > dc_journ_Haute-Vienne
# > hosp_comp_vagues_Haute-Vienne
# > saturation_rea_journ_Haute-Vienne
# > cas_journ_Hautes-Alpes
# > hosp_journ_Hautes-Alpes
# > rea_journ_Hautes-Alpes
# > dc_journ_Hautes-Alpes
# > hosp_comp_vagues_Hautes-Alpes
# > saturation_rea_journ_Hautes-Alpes
# > cas_journ_Hautes-Pyrénées
# > hosp_journ_Hautes-Pyrénées
# > rea_journ_Hautes-Pyrénées
# > dc_journ_Hautes-Pyrénées
# > hosp_comp_vagues_Hautes-Pyrénées
# > saturation_rea_journ_Hautes-Pyrénées
# > cas_journ_Hauts-de-Seine
# > hosp_journ_Hauts-de-Seine
# > rea_journ_Hauts-de-Seine
# > dc_journ_Hauts-de-Seine
# > hosp_comp_vagues_Hauts-de-Seine
# > saturation_rea_journ_Hauts-de-Seine
# > cas_journ_Hérault
# > hosp_journ_Hérault
# > rea_journ_Hérault
# > dc_journ_Hérault
# > hosp_comp_vagues_Hérault
# > saturation_rea_journ_Hérault
# > cas_journ_Ille-et-Vilaine
# > hosp_journ_Ille-et-Vilaine
# > rea_journ_Ille-et-Vilaine
# > dc_journ_Ille-et-Vilaine
# > hosp_comp_vagues_Ille-et-Vilaine
# > saturation_rea_journ_Ille-et-Vilaine
# > cas_journ_Indre
# > hosp_journ_Indre
# > rea_journ_Indre
# > dc_journ_Indre
# > hosp_comp_vagues_Indre
# > saturation_rea_journ_Indre
# > cas_journ_Indre-et-Loire
# > hosp_journ_Indre-et-Loire
# > rea_journ_Indre-et-Loire
# > dc_journ_Indre-et-Loire
# > hosp_comp_vagues_Indre-et-Loire
# > saturation_rea_journ_Indre-et-Loire
# > cas_journ_Isère
# > hosp_journ_Isère
# > rea_journ_Isère
# > dc_journ_Isère
# > hosp_comp_vagues_Isère
# > saturation_rea_journ_Isère
# > cas_journ_Jura
# > hosp_journ_Jura
# > rea_journ_Jura
# > dc_journ_Jura
# > hosp_comp_vagues_Jura
# > saturation_rea_journ_Jura
# > cas_journ_La Réunion
# > hosp_journ_La Réunion
# > rea_journ_La Réunion
# > dc_journ_La Réunion
# > hosp_comp_vagues_La Réunion
# > saturation_rea_journ_La Réunion
# > cas_journ_Landes
# > hosp_journ_Landes
# > rea_journ_Landes
# > dc_journ_Landes
# > hosp_comp_vagues_Landes
# > saturation_rea_journ_Landes
# > cas_journ_Loir-et-Cher
# > hosp_journ_Loir-et-Cher
# > rea_journ_Loir-et-Cher
# > dc_journ_Loir-et-Cher
# > hosp_comp_vagues_Loir-et-Cher
# > saturation_rea_journ_Loir-et-Cher
# > cas_journ_Loire
# > hosp_journ_Loire
# > rea_journ_Loire
# > dc_journ_Loire
# > hosp_comp_vagues_Loire
# > saturation_rea_journ_Loire
# > cas_journ_Loire-Atlantique
# > hosp_journ_Loire-Atlantique
# > rea_journ_Loire-Atlantique
# > dc_journ_Loire-Atlantique
# > hosp_comp_vagues_Loire-Atlantique
# > saturation_rea_journ_Loire-Atlantique
# > cas_journ_Loiret
# > hosp_journ_Loiret
# > rea_journ_Loiret
# > dc_journ_Loiret
# > hosp_comp_vagues_Loiret
# > saturation_rea_journ_Loiret
# > cas_journ_Lot
# > hosp_journ_Lot
# > rea_journ_Lot
# > dc_journ_Lot
# > hosp_comp_vagues_Lot
# > saturation_rea_journ_Lot
# > cas_journ_Lot-et-Garonne
# > hosp_journ_Lot-et-Garonne
# > rea_journ_Lot-et-Garonne
# > dc_journ_Lot-et-Garonne
# > hosp_comp_vagues_Lot-et-Garonne
# > saturation_rea_journ_Lot-et-Garonne
# > cas_journ_Lozère
# > hosp_journ_Lozère
# > rea_journ_Lozère
# > dc_journ_Lozère
# > hosp_comp_vagues_Lozère
# > saturation_rea_journ_Lozère
# > cas_journ_Maine-et-Loire
# > hosp_journ_Maine-et-Loire
# > rea_journ_Maine-et-Loire
# > dc_journ_Maine-et-Loire
# > hosp_comp_vagues_Maine-et-Loire
# > saturation_rea_journ_Maine-et-Loire
# > cas_journ_Manche
# > hosp_journ_Manche
# > rea_journ_Manche
# > dc_journ_Manche
# > hosp_comp_vagues_Manche
# > saturation_rea_journ_Manche
# > cas_journ_Marne
# > hosp_journ_Marne
# > rea_journ_Marne
# > dc_journ_Marne
# > hosp_comp_vagues_Marne
# > saturation_rea_journ_Marne
# > cas_journ_Martinique
# > hosp_journ_Martinique
# > rea_journ_Martinique
# > dc_journ_Martinique
# > hosp_comp_vagues_Martinique
# > saturation_rea_journ_Martinique
# > cas_journ_Mayenne
# > hosp_journ_Mayenne
# > rea_journ_Mayenne
# > dc_journ_Mayenne
# > hosp_comp_vagues_Mayenne
# > saturation_rea_journ_Mayenne
# > cas_journ_Mayotte
# > hosp_journ_Mayotte
# > rea_journ_Mayotte
# > dc_journ_Mayotte
# > hosp_comp_vagues_Mayotte
# > saturation_rea_journ_Mayotte
# > cas_journ_Meurthe-et-Moselle
# > hosp_journ_Meurthe-et-Moselle
# > rea_journ_Meurthe-et-Moselle
# > dc_journ_Meurthe-et-Moselle
# > hosp_comp_vagues_Meurthe-et-Moselle
# > saturation_rea_journ_Meurthe-et-Moselle
# > cas_journ_Meuse
# > hosp_journ_Meuse
# > rea_journ_Meuse
# > dc_journ_Meuse
# > hosp_comp_vagues_Meuse
# > saturation_rea_journ_Meuse
# > cas_journ_Morbihan
# > hosp_journ_Morbihan
# > rea_journ_Morbihan
# > dc_journ_Morbihan
# > hosp_comp_vagues_Morbihan
# > saturation_rea_journ_Morbihan
# > cas_journ_Moselle
# > hosp_journ_Moselle
# > rea_journ_Moselle
# > dc_journ_Moselle
# > hosp_comp_vagues_Moselle
# > saturation_rea_journ_Moselle
# > cas_journ_Nièvre
# > hosp_journ_Nièvre
# > rea_journ_Nièvre
# > dc_journ_Nièvre
# > hosp_comp_vagues_Nièvre
# > saturation_rea_journ_Nièvre
# > cas_journ_Nord
# > hosp_journ_Nord
# > rea_journ_Nord
# > dc_journ_Nord
# > hosp_comp_vagues_Nord
# > saturation_rea_journ_Nord
# > cas_journ_Oise
# > hosp_journ_Oise
# > rea_journ_Oise
# > dc_journ_Oise
# > hosp_comp_vagues_Oise
# > saturation_rea_journ_Oise
# > cas_journ_Orne
# > hosp_journ_Orne
# > rea_journ_Orne
# > dc_journ_Orne
# > hosp_comp_vagues_Orne
# > saturation_rea_journ_Orne
# > cas_journ_Paris
# > hosp_journ_Paris
# > rea_journ_Paris
# > dc_journ_Paris
# > hosp_comp_vagues_Paris
# > saturation_rea_journ_Paris
# > cas_journ_Pas-de-Calais
# > hosp_journ_Pas-de-Calais
# > rea_journ_Pas-de-Calais
# > dc_journ_Pas-de-Calais
# > hosp_comp_vagues_Pas-de-Calais
# > saturation_rea_journ_Pas-de-Calais
# > cas_journ_Puy-de-Dôme
# > hosp_journ_Puy-de-Dôme
# > rea_journ_Puy-de-Dôme
# > dc_journ_Puy-de-Dôme
# > hosp_comp_vagues_Puy-de-Dôme
# > saturation_rea_journ_Puy-de-Dôme
# > cas_journ_Pyrénées-Atlantiques
# > hosp_journ_Pyrénées-Atlantiques
# > rea_journ_Pyrénées-Atlantiques
# > dc_journ_Pyrénées-Atlantiques
# > hosp_comp_vagues_Pyrénées-Atlantiques
# > saturation_rea_journ_Pyrénées-Atlantiques
# > cas_journ_Pyrénées-Orientales
# > hosp_journ_Pyrénées-Orientales
# > rea_journ_Pyrénées-Orientales
# > dc_journ_Pyrénées-Orientales
# > hosp_comp_vagues_Pyrénées-Orientales
# > saturation_rea_journ_Pyrénées-Orientales
# > cas_journ_Rhône
# > hosp_journ_Rhône
# > rea_journ_Rhône
# > dc_journ_Rhône
# > hosp_comp_vagues_Rhône
# > saturation_rea_journ_Rhône
# > cas_journ_Sarthe
# > hosp_journ_Sarthe
# > rea_journ_Sarthe
# > dc_journ_Sarthe
# > hosp_comp_vagues_Sarthe
# > saturation_rea_journ_Sarthe
# > cas_journ_Savoie
# > hosp_journ_Savoie
# > rea_journ_Savoie
# > dc_journ_Savoie
# > hosp_comp_vagues_Savoie
# > saturation_rea_journ_Savoie
# > cas_journ_Saône-et-Loire
# > hosp_journ_Saône-et-Loire
# > rea_journ_Saône-et-Loire
# > dc_journ_Saône-et-Loire
# > hosp_comp_vagues_Saône-et-Loire
# > saturation_rea_journ_Saône-et-Loire
# > cas_journ_Seine-Maritime
# > hosp_journ_Seine-Maritime
# > rea_journ_Seine-Maritime
# > dc_journ_Seine-Maritime
# > hosp_comp_vagues_Seine-Maritime
# > saturation_rea_journ_Seine-Maritime
# > cas_journ_Seine-Saint-Denis
# > hosp_journ_Seine-Saint-Denis
# > rea_journ_Seine-Saint-Denis
# > dc_journ_Seine-Saint-Denis
# > hosp_comp_vagues_Seine-Saint-Denis
# > saturation_rea_journ_Seine-Saint-Denis
# > cas_journ_Seine-et-Marne
# > hosp_journ_Seine-et-Marne
# > rea_journ_Seine-et-Marne
# > dc_journ_Seine-et-Marne
# > hosp_comp_vagues_Seine-et-Marne
# > saturation_rea_journ_Seine-et-Marne
# > cas_journ_Somme
# > hosp_journ_Somme
# > rea_journ_Somme
# > dc_journ_Somme
# > hosp_comp_vagues_Somme
# > saturation_rea_journ_Somme
# > cas_journ_Tarn
# > hosp_journ_Tarn
# > rea_journ_Tarn
# > dc_journ_Tarn
# > hosp_comp_vagues_Tarn
# > saturation_rea_journ_Tarn
# > cas_journ_Tarn-et-Garonne
# > hosp_journ_Tarn-et-Garonne
# > rea_journ_Tarn-et-Garonne
# > dc_journ_Tarn-et-Garonne
# > hosp_comp_vagues_Tarn-et-Garonne
# > saturation_rea_journ_Tarn-et-Garonne
# > cas_journ_Territoire de Belfort
# > hosp_journ_Territoire de Belfort
# > rea_journ_Territoire de Belfort
# > dc_journ_Territoire de Belfort
# > hosp_comp_vagues_Territoire de Belfort
# > saturation_rea_journ_Territoire de Belfort
# > cas_journ_Val-d'oise
# > hosp_journ_Val-d'oise
# > rea_journ_Val-d'oise
# > dc_journ_Val-d'oise
# > hosp_comp_vagues_Val-d'oise
# > saturation_rea_journ_Val-d'oise
# > cas_journ_Val-de-Marne
# > hosp_journ_Val-de-Marne
# > rea_journ_Val-de-Marne
# > dc_journ_Val-de-Marne
# > hosp_comp_vagues_Val-de-Marne
# > saturation_rea_journ_Val-de-Marne
# > cas_journ_Var
# > hosp_journ_Var
# > rea_journ_Var
# > dc_journ_Var
# > hosp_comp_vagues_Var
# > saturation_rea_journ_Var
# > cas_journ_Vaucluse
# > hosp_journ_Vaucluse
# > rea_journ_Vaucluse
# > dc_journ_Vaucluse
# > hosp_comp_vagues_Vaucluse
# > saturation_rea_journ_Vaucluse
# > cas_journ_Vendée
# > hosp_journ_Vendée
# > rea_journ_Vendée
# > dc_journ_Vendée
# > hosp_comp_vagues_Vendée
# > saturation_rea_journ_Vendée
# > cas_journ_Vienne
# > hosp_journ_Vienne
# > rea_journ_Vienne
# > dc_journ_Vienne
# > hosp_comp_vagues_Vienne
# > saturation_rea_journ_Vienne
# > cas_journ_Vosges
# > hosp_journ_Vosges
# > rea_journ_Vosges
# > dc_journ_Vosges
# > hosp_comp_vagues_Vosges
# > saturation_rea_journ_Vosges
# > cas_journ_Yonne
# > hosp_journ_Yonne
# > rea_journ_Yonne
# > dc_journ_Yonne
# > hosp_comp_vagues_Yonne
# > saturation_rea_journ_Yonne
# > cas_journ_Yvelines
# > hosp_journ_Yvelines
# > rea_journ_Yvelines
# > dc_journ_Yvelines
# > hosp_comp_vagues_Yvelines
# > saturation_rea_journ_Yvelines

# %%
for dep in departements:
    saturation_rea_journ(dep)
# Out:
# > saturation_rea_journ_Ain
# > saturation_rea_journ_Aisne
# > saturation_rea_journ_Allier
# > saturation_rea_journ_Alpes-Maritimes
# > saturation_rea_journ_Alpes-de-Haute-Provence
# > saturation_rea_journ_Ardennes
# > saturation_rea_journ_Ardèche
# > saturation_rea_journ_Ariège
# > saturation_rea_journ_Aube
# > saturation_rea_journ_Aude
# > saturation_rea_journ_Aveyron
# > saturation_rea_journ_Bas-Rhin
# > saturation_rea_journ_Bouches-du-Rhône
# > saturation_rea_journ_Calvados
# > saturation_rea_journ_Cantal
# > saturation_rea_journ_Charente
# > saturation_rea_journ_Charente-Maritime
# > saturation_rea_journ_Cher
# > saturation_rea_journ_Corrèze
# > saturation_rea_journ_Corse-du-Sud
# > saturation_rea_journ_Creuse
# > saturation_rea_journ_Côte-d'or
# > saturation_rea_journ_Côtes-d'armor
# > saturation_rea_journ_Deux-Sèvres
# > saturation_rea_journ_Dordogne
# > saturation_rea_journ_Doubs
# > saturation_rea_journ_Drôme
# > saturation_rea_journ_Essonne
# > saturation_rea_journ_Eure
# > saturation_rea_journ_Eure-et-Loir
# > saturation_rea_journ_Finistère
# > saturation_rea_journ_Gard
# > saturation_rea_journ_Gers
# > saturation_rea_journ_Gironde
# > saturation_rea_journ_Guadeloupe
# > saturation_rea_journ_Guyane
# > saturation_rea_journ_Haut-Rhin
# > saturation_rea_journ_Haute-Corse
# > saturation_rea_journ_Haute-Garonne
# > saturation_rea_journ_Haute-Loire
# > saturation_rea_journ_Haute-Marne
# > saturation_rea_journ_Haute-Savoie
# > saturation_rea_journ_Haute-Saône
# > saturation_rea_journ_Haute-Vienne
# > saturation_rea_journ_Hautes-Alpes
# > saturation_rea_journ_Hautes-Pyrénées
# > saturation_rea_journ_Hauts-de-Seine
# > saturation_rea_journ_Hérault
# > saturation_rea_journ_Ille-et-Vilaine
# > saturation_rea_journ_Indre
# > saturation_rea_journ_Indre-et-Loire
# > saturation_rea_journ_Isère
# > saturation_rea_journ_Jura
# > saturation_rea_journ_La Réunion
# > saturation_rea_journ_Landes
# > saturation_rea_journ_Loir-et-Cher
# > saturation_rea_journ_Loire
# > saturation_rea_journ_Loire-Atlantique
# > saturation_rea_journ_Loiret
# > saturation_rea_journ_Lot
# > saturation_rea_journ_Lot-et-Garonne
# > saturation_rea_journ_Lozère
# > saturation_rea_journ_Maine-et-Loire
# > saturation_rea_journ_Manche
# > saturation_rea_journ_Marne
# > saturation_rea_journ_Martinique
# > saturation_rea_journ_Mayenne
# > saturation_rea_journ_Mayotte
# > saturation_rea_journ_Meurthe-et-Moselle
# > saturation_rea_journ_Meuse
# > saturation_rea_journ_Morbihan
# > saturation_rea_journ_Moselle
# > saturation_rea_journ_Nièvre
# > saturation_rea_journ_Nord
# > saturation_rea_journ_Oise
# > saturation_rea_journ_Orne
# > saturation_rea_journ_Paris
# > saturation_rea_journ_Pas-de-Calais
# > saturation_rea_journ_Puy-de-Dôme
# > saturation_rea_journ_Pyrénées-Atlantiques
# > saturation_rea_journ_Pyrénées-Orientales
# > saturation_rea_journ_Rhône
# > saturation_rea_journ_Sarthe
# > saturation_rea_journ_Savoie
# > saturation_rea_journ_Saône-et-Loire
# > saturation_rea_journ_Seine-Maritime
# > saturation_rea_journ_Seine-Saint-Denis
# > saturation_rea_journ_Seine-et-Marne
# > saturation_rea_journ_Somme
# > saturation_rea_journ_Tarn
# > saturation_rea_journ_Tarn-et-Garonne
# > saturation_rea_journ_Territoire de Belfort
# > saturation_rea_journ_Val-d'oise
# > saturation_rea_journ_Val-de-Marne
# > saturation_rea_journ_Var
# > saturation_rea_journ_Vaucluse
# > saturation_rea_journ_Vendée
# > saturation_rea_journ_Vienne
# > saturation_rea_journ_Vosges
# > saturation_rea_journ_Yonne
# > saturation_rea_journ_Yvelines

# %%
"""for idx,dep in enumerate(departements):
    numero_dep = df[df["departmentName"] == dep]["dep"].values[-1]
    
    heading = "<!-- wp:heading --><h2 id=\"{}\">{}</h2><!-- /wp:heading -->\n".format(dep, dep + " (" + numero_dep + ")")
    string = "<p align=\"center\"> <a href=\"https://raw.githubusercontent.com/rozierguillaume/covid-19/master/images/charts/france/departements_dashboards/dashboard_jour_{}.jpeg\" target=\"_blank\" rel=\"noopener noreferrer\"><img src=\"https://raw.githubusercontent.com/rozierguillaume/covid-19/master/images/charts/france/departements_dashboards/dashboard_jour_{}.jpeg\" width=\"75%\"> </a></p>\n".format(dep, dep)
    string2 = "<p align=\"center\"> <a href=\"https://raw.githubusercontent.com/rozierguillaume/covid-19/master/images/charts/france/heatmaps_deps/heatmap_taux_{}.jpeg\" target=\"_blank\" rel=\"noopener noreferrer\"><img src=\"https://raw.githubusercontent.com/rozierguillaume/covid-19/master/images/charts/france/heatmaps_deps/heatmap_taux_{}.jpeg\" width=\"60%\"> </a></p>\n".format(numero_dep, numero_dep)
    string_saturation = "<p align=\"center\"> <a href=\"https://raw.githubusercontent.com/rozierguillaume/covid-19/master/images/charts/france/departements_dashboards/saturation_rea_journ_{}.jpeg\" target=\"_blank\" rel=\"noopener noreferrer\"><img src=\"https://raw.githubusercontent.com/rozierguillaume/covid-19/master/images/charts/france/departements_dashboards/saturation_rea_journ_{}.jpeg\" width=\"60%\"> </a></p>\n".format(dep, dep)
    space = "<!-- wp:spacer {\"height\":50} --><div style=\"height:50px\" aria-hidden=\"true\" class=\"wp-block-spacer\"></div><!-- /wp:spacer -->"
    retourmenu="<a href=\"#Menu\">Retour au menu</a>"
    print(space+retourmenu+heading+string+string2+string_saturation)
"""
# Out:
# 'for idx,dep in enumerate(departements):\n    numero_dep = df[df["departmentName"] == dep]["dep"].values[-1]\n    \n    heading = "<!-- wp:heading --><h2 id="{}">{}</h2><!-- /wp:heading -->\n".format(dep, dep + " (" + numero_dep + ")")\n    string = "<p align="center"> <a href="https://raw.githubusercontent.com/rozierguillaume/covid-19/master/images/charts/france/departements_dashboards/dashboard_jour_{}.jpeg" target="_blank" rel="noopener noreferrer"><img src="https://raw.githubusercontent.com/rozierguillaume/covid-19/master/images/charts/france/departements_dashboards/dashboard_jour_{}.jpeg" width="75%"> </a></p>\n".format(dep, dep)\n    string2 = "<p align="center"> <a href="https://raw.githubusercontent.com/rozierguillaume/covid-19/master/images/charts/france/heatmaps_deps/heatmap_taux_{}.jpeg" target="_blank" rel="noopener noreferrer"><img src="https://raw.githubusercontent.com/rozierguillaume/covid-19/master/images/charts/france/heatmaps_deps/heatmap_taux_{}.jpeg" width="60%"> </a></p>\n".format(numero_dep, numero_dep)\n    string_saturation = "<p align="center"> <a href="https://raw.githubusercontent.com/rozierguillaume/covid-19/master/images/charts/france/departements_dashboards/saturation_rea_journ_{}.jpeg" target="_blank" rel="noopener noreferrer"><img src="https://raw.githubusercontent.com/rozierguillaume/covid-19/master/images/charts/france/departements_dashboards/saturation_rea_journ_{}.jpeg" width="60%"> </a></p>\n".format(dep, dep)\n    space = "<!-- wp:spacer {"height":50} --><div style="height:50px" aria-hidden="true" class="wp-block-spacer"></div><!-- /wp:spacer -->"\n    retourmenu="<a href="#Menu">Retour au menu</a>"\n    print(space+retourmenu+heading+string+string2+string_saturation)\n'

# %%
"""#print("<!-- wp:buttons --><div class=\"wp-block-buttons\">\n")
output = ""
for dep in departements:
    numero_dep = df[df["departmentName"] == dep]["dep"].values[-1]
    output+= "<a href=\"#{}\">{} ({})</a> • ".format(dep, dep, numero_dep)
#print(output[:-2])

"""
#print("<!-- /wp:buttons -->")
# Out:
# '#print("<!-- wp:buttons --><div class="wp-block-buttons">\n")\noutput = ""\nfor dep in departements:\n    numero_dep = df[df["departmentName"] == dep]["dep"].values[-1]\n    output+= "<a href="#{}">{} ({})</a> • ".format(dep, dep, numero_dep)\n#print(output[:-2])\n\n'
